# %% [markdown]
# print("Hello World")
# EXAMPLE = 5 + 5
# print("EXAMPLE")

# %%
if EXAMPLE != 10:
    print("The variable is not euqal to 10")
else:
    print("Congrats! You found the correct number!")
# Out:
# Congrats! You found the correct number!

# %% [markdown]
# import Hello print() Thisn is Markdown

# %%
import leafmap.maplibregl as leafmap

# %%
m = leafmap.Map(style="liberty", projection="globe")
m
# Out:
# Html(children=[Map(calls=[['addControl', ('NavigationControl', {'showCompass': True, 'showZoom': True, 'visual…
